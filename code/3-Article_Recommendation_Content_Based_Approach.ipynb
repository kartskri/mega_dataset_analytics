# %%
import numpy as np
import pandas as pd
import dask.dataframe as dd
from scipy import stats
from matplotlib.pyplot import figure
from sklearn.metrics.pairwise import cosine_similarity
from scipy.sparse import csr_matrix
import warnings

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction import text

warnings.filterwarnings("ignore")
# %matplotlib inline

# %% [markdown]
# ## Content Based Recomemndations
#
# We try to related articles based on their category, garment group and description and try to build a sparse matrix mapping out their similarities. This is a non personalized recommendation but understanding similar products (articles in this case) is necessary to build a model.

# %%
path = "../files/"
articles_df = pd.read_csv(path + "articles.csv",
                          dtype={
                            "article_id": int,
                            "product_code": int,
                            "product_type_no": int,
                            "graphical_appearance_no": int,
                            "index_group_no": int,
                            "section_no": int,
                            "garment_group_no": int
                          })
articles_df.dropna(inplace = True)
articles_df.shape
# Out:
# (105126, 25)

# %%
articles_df['index_group_name'].value_counts()
# Out:
# Ladieswear       39523
# Baby/Children    34619
# Divided          15086
# Menswear         12539
# Sport             3359
# Name: index_group_name, dtype: int64

# %% [markdown]
# ## Similarities within Groups
# Considering the Dataset is too large and similarities finding is very costly operation letz try to ascertain similarities
# within groups of the dataset using cosine similarity

# %%
Groups = articles_df['index_group_name'].value_counts().index
similarity_sparse_matrix = []
# Iterate groups from the H&M
for group in Groups:
    # Fetch the Articles Pertaining to the group
    df = articles_df[articles_df['index_group_name'] == group]
    # Concatenate the cotent for the particular product
    df['content_for_analyis'] = df['product_type_name'] + ' ' + articles_df['product_group_name'] + ' ' + articles_df['graphical_appearance_name'] + ' ' + articles_df['colour_group_name'] + ' ' + articles_df['department_name'] + ' ' + articles_df['section_name'] + ' ' + articles_df['garment_group_name']
    # Build the Dataframe for content based similarity index
    item_keywords_df = df[['article_id', 'content_for_analyis']]
    # TF IDF Vectorization
    vectorizer = TfidfVectorizer(min_df=3, max_df=0.7, stop_words=text.ENGLISH_STOP_WORDS)
    # Do a TD IDF Analysis
    X = vectorizer.fit_transform(item_keywords_df['content_for_analyis'])
    # Get the Vectorized_data
    vectorized_data = vectorizer.get_feature_names_out()
    # Print 
    print(group)
    print("-----")
    print("FeatureSet")
    print(vectorized_data)
    # Build the TF IDF Data Frame
    tfidf_df = pd.DataFrame(X.toarray(), columns=vectorizer.get_feature_names())
    tfidf_df.index = df['article_id']
    # Compute the Cosine Similarities
    cosine_similarity_array = cosine_similarity(tfidf_df)
    # Append it to the top level cosine similarilty array
    similarity_sparse_matrix.append(cosine_similarity_array)
# Out:
# Ladieswear
# -----
# FeatureSet
# ['3d' 'accessories' 'alice' 'application' 'asia' 'assortment' 'bag' 'bags'
#  'ballerinas' 'band' 'basic' 'basics' 'beachwear' 'beanie' 'beige' 'belt'
#  'belts' 'big' 'bikini' 'black' 'blazer' 'blazers' 'blocking' 'blouse'
#  'blouses' 'blue' 'body' 'bodysuit' 'bootie' 'boots' 'bottoms' 'bra'
#  'bracelet' 'brim' 'bronze' 'brown' 'campaigns' 'cap' 'cardigan' 'care'
#  'case' 'casual' 'chambray' 'check' 'clean' 'clip' 'coat' 'collaborations'
#  'collection' 'collections' 'colour' 'conscious' 'contrast' 'copper'
#  'corset' 'covers' 'dark' 'denim' 'divided' 'dog' 'dot' 'dress' 'dressed'
#  'dresses' 'dungarees' 'earring' 'earrings' 'edition' 'embroidery' 'eq'
#  'equatorial' 'everyday' 'exclusive' 'expressive' 'extended' 'external'
#  'fancy' 'flat' 'flats' 'flip' 'flop' 'functional' 'furniture' 'garment'
#  'glittering' 'gloves' 'gold' 'gown' 'green' 'greenish' 'grey' 'greyish'
#  'hair' 'hat' 'hats' 'head' 'heeled' 'heels' 'hoodie' 'inactive' 'items'
#  'jacket' 'jackets' 'jacquard' 'jersey' 'jewellery' 'jumpsuit' 'khaki'
#  'knitwear' 'lace' 'ladies' 'leggings' 'license' 'light' 'limited'
#  'lingerie' 'loungewear' 'lower' 'mama' 'marker' 'melange' 'mesh'
#  'metallic' 'mixed' 'mobile' 'necklace' 'neps' 'night' 'nightwear'
#  'nipple' 'nursing' 'occasion' 'offers' 'ol' 'orange' 'outdoor' 'outwear'
#  'pattern' 'peaked' 'pen' 'pink' 'placement' 'playsuit' 'polo' 'premium'
#  'print' 'pumps' 'purple' 'pyjama' 'quality' 'red' 'ring' 'robe' 'sandals'
#  'sarong' 'scarf' 'scarves' 'sequin' 'set' 'shirt' 'shoe' 'shoes'
#  'shopbasket' 'shorts' 'silver' 'sizes' 'skirt' 'skirts' 'slippers' 'slub'
#  'small' 'sneakers' 'socks' 'solid' 'special' 'stationery' 'string'
#  'stripe' 'structure' 'studio' 'suit' 'sunglasses' 'sweater' 'swimsuit'
#  'swimwear' 'table' 'tailoring' 'test' 'ties' 'tigh' 'tights' 'tops'
#  'transparent' 'treatment' 'trend' 'trouser' 'trousers' 'turquoise'
#  'umbrella' 'underdress' 'underwear' 'unknown' 'upper' 'vest' 'waistcoat'
#  'wallet' 'waredrobe' 'watch' 'wear' 'wedge' 'white' 'woven' 'yellow'
#  'yellowish' 'zipper']
# Baby/Children
# -----
# FeatureSet
# ['3d' 'acc' 'accessories' 'alice' 'application' 'argyle' 'baby' 'bag'
#  'bags' 'ballerinas' 'band' 'basic' 'basics' 'beanie' 'beige' 'belt' 'bib'
#  'big' 'black' 'blazer' 'blocking' 'blouse' 'blue' 'bodysuit' 'bootie'
#  'boots' 'boy' 'boys' 'bracelet' 'brim' 'bronze' 'brown' 'cap' 'cardigan'
#  'chambray' 'check' 'chem' 'clip' 'coat' 'colour' 'complements' 'contrast'
#  'copper' 'cosmetic' 'cosmetics' 'costumes' 'dark' 'denim' 'dot' 'dress'
#  'dresses' 'dungarees' 'embroidery' 'essentials' 'exclusive' 'fancy'
#  'fine' 'flat' 'flip' 'flop' 'football' 'giftbox' 'girl' 'girls'
#  'glittering' 'gloves' 'gold' 'gown' 'green' 'greenish' 'grey' 'greyish'
#  'hair' 'hat' 'hoodie' 'inactive' 'interior' 'jacket' 'jacquard' 'jersey'
#  'jewellery' 'john' 'jumpsuit' 'khaki' 'kids' 'knitted' 'knitwear' 'lace'
#  'leg' 'leggings' 'license' 'light' 'local' 'long' 'lower' 'melange'
#  'mesh' 'metallic' 'mix' 'mixed' 'moccasins' 'necklace' 'neps' 'newborn'
#  'night' 'nightwear' 'nw' 'offer' 'offers' 'orange' 'outdoor' 'outerwear'
#  'overall' 'pattern' 'peaked' 'pink' 'placement' 'playsuit' 'polo' 'print'
#  'projects' 'promotion' 'purple' 'pyjama' 'red' 'relevance' 'robe' 's2'
#  'sack' 'sandals' 'scarf' 'sequin' 'set' 'shirt' 'shirts' 'shoe' 'shoes'
#  'shorts' 'silver' 'skirt' 'skirts' 'sleep' 'sleeping' 'slippers' 'slub'
#  'small' 'sneakers' 'socks' 'soft' 'solid' 'special' 'string' 'stripe'
#  'structure' 'sunglasses' 'sweater' 'swimsuit' 'swimwear' 'tailored'
#  'textile' 'tie' 'tights' 'toys' 'transparent' 'treatment' 'trouser'
#  'trousers' 'turquoise' 'underwear' 'unknown' 'upper' 'uw' 'vest'
#  'waistcoat' 'warmers' 'waterbottle' 'white' 'woven' 'yellow' 'yellowish'
#  'young']
# Divided
# -----
# FeatureSet
# ['3d' 'accessories' 'ak' 'alice' 'application' 'asia' 'backpack' 'bag'
#  'bags' 'ballerinas' 'band' 'basic' 'basics' 'beanie' 'beige' 'belt'
#  'bikini' 'black' 'blazer' 'blazers' 'blocking' 'blouse' 'blouses' 'blue'
#  'bodysuit' 'boots' 'bottoms' 'bra' 'bracelet' 'brim' 'brown' 'cap'
#  'cardigan' 'chambray' 'check' 'clip' 'coat' 'collection' 'colour'
#  'complements' 'contrast' 'dark' 'denim' 'dot' 'dress' 'dresses' 'ds'
#  'dungarees' 'earring' 'embroidery' 'eq' 'equatorial' 'extended' 'fancy'
#  'flat' 'flip' 'flop' 'garments' 'glittering' 'gloves' 'gold' 'green'
#  'greenish' 'grey' 'greyish' 'gym' 'hair' 'hat' 'hologram' 'hoodie'
#  'items' 'jacket' 'jacquard' 'jersey' 'jumpsuit' 'keys' 'khaki' 'knit'
#  'knitwear' 'lace' 'ladies' 'leggings' 'light' 'lower' 'melange' 'mesh'
#  'metallic' 'mixed' 'necklace' 'nightwear' 'offer' 'offers' 'ol' 'orange'
#  'outdoor' 'pattern' 'peaked' 'pink' 'placement' 'playsuit' 'polo' 'price'
#  'print' 'projects' 'promotion' 'pumps' 'purple' 'react' 'read' 'red'
#  'ring' 'sandals' 'scarf' 'selected' 'sequin' 'set' 'shirt' 'shoe' 'shoes'
#  'shorts' 'silver' 'sizes' 'skirt' 'skirts' 'small' 'sneakers' 'socks'
#  'solid' 'special' 'straw' 'string' 'stripe' 'structure' 'sunglasses'
#  'sweater' 'swimsuit' 'swimwear' 'tights' 'tops' 'transparent' 'treatment'
#  'trousers' 'turquoise' 'umbrella' 'underwear' 'unknown' 'upper' 'uw'
#  'vest' 'waistcoat' 'wallet' 'waterbottle' 'weekend' 'white' 'woven'
#  'yellow' 'yellowish']
# Menswear
# -----
# FeatureSet
# ['3d' 'accessories' 'application' 'argyle' 'bag' 'bags' 'basic' 'basics'
#  'beanie' 'beige' 'belt' 'belts' 'bin' 'black' 'blanks' 'blazer'
#  'blocking' 'blue' 'boots' 'bra' 'bracelet' 'braces' 'brim' 'brown'
#  'bucket' 'cap' 'cardigan' 'casual' 'chambray' 'check' 'coat' 'colour'
#  'contemporary' 'contrast' 'dark' 'demand' 'denim' 'dot' 'dressed'
#  'earring' 'edition' 'embroidery' 'eq' 'extended' 'fancy' 'felt' 'flat'
#  'flip' 'flop' 'glittering' 'gloves' 'gold' 'green' 'greenish' 'grey'
#  'greyish' 'gym' 'hat' 'heavy' 'hoodie' 'inactive' 'items' 'jacket'
#  'jacquard' 'jersey' 'john' 'jumpsuit' 'khaki' 'knitwear' 'license'
#  'light' 'local' 'long' 'loungewear' 'lower' 'man' 'melange' 'men' 'mens'
#  'mesh' 'metallic' 'mixed' 'necklace' 'neps' 'nightwear' 'offer' 'offers'
#  'orange' 'outdoor' 'outerwear' 'pattern' 'peaked' 'pink' 'placement'
#  'playsuit' 'polo' 'print' 'project' 'projects' 'promotion' 'purple'
#  'pyjama' 'red' 'relevance' 'ring' 'robe' 's1' 's5' 'sandals' 'scarf'
#  'set' 'shirt' 'shirts' 'shoe' 'shoes' 'shorts' 'silver' 'slippers' 'slub'
#  'small' 'smart' 'sneakers' 'socks' 'solid' 'special' 'street' 'stripe'
#  'structure' 'suit' 'suits' 'sunglasses' 'sweater' 'swimwear' 'tailored'
#  'tailoring' 'tie' 'tights' 'transparent' 'treatment' 'trouser' 'trousers'
#  'turquoise' 'underwear' 'unknown' 'upper' 'vest' 'waistcoat' 'wall'
#  'wallet' 'wardrobe' 'watch' 'weekend' 'white' 'woven' 'yellow'
#  'yellowish']
# Sport
# -----
# FeatureSet
# ['acc' 'accessories' 'bag' 'beanie' 'beige' 'bikini' 'black' 'blocking'
#  'blue' 'bottoms' 'boys' 'bra' 'bras' 'brown' 'cap' 'colour' 'contrast'
#  'dark' 'fancy' 'girls' 'glittering' 'gloves' 'green' 'greenish' 'grey'
#  'greyish' 'hair' 'hat' 'hoodie' 'jacket' 'jacquard' 'jersey' 'khaki'
#  'kids' 'ladies' 'leggings' 'light' 'lower' 'melange' 'men' 'mesh'
#  'metallic' 'mixed' 'orange' 'outdoor' 'pattern' 'peaked' 'pink'
#  'placement' 'print' 'purple' 'red' 'set' 'shirt' 'shorts' 'slub' 'socks'
#  'solid' 'sports' 'string' 'stripe' 'structure' 'sweater' 'swimsuit'
#  'swimwear' 'tights' 'tops' 'trousers' 'turquoise' 'underwear' 'unknown'
#  'upper' 'vest' 'waistcoat' 'waterbottle' 'white' 'woven' 'yellow'
#  'yellowish']

# %%
len(similarity_sparse_matrix[0]), len(similarity_sparse_matrix[0][0])
# Out:
# (39523, 39523)

# %%
# Finding the similarity in products - Processing Group "LadiesWear"
group = 'Ladieswear'
Ladieswear_df = pd.DataFrame(data=similarity_sparse_matrix[0], 
                             index=articles_df[articles_df['index_group_name'] == group]['article_id'].values,
                             columns=articles_df[articles_df['index_group_name'] == group]['article_id'].values)
Ladieswear_df
# Out:
#            108775015  108775044  108775051  110065001  110065002  110065011  \
# 108775015   1.000000   0.953124   0.897246   0.056032   0.016275   0.015723
# 108775044   0.953124   1.000000   0.942233   0.016313   0.079269   0.015545
# 108775051   0.897246   0.942233   1.000000   0.000000   0.060415   0.000000
# 110065001   0.056032   0.016313   0.000000   1.000000   0.943576   0.911566
# 110065002   0.016275   0.079269   0.060415   0.943576   1.000000   0.899182
# ...              ...        ...        ...        ...        ...        ...
# 952937003   0.277282   0.274150   0.262162   0.000000   0.000000   0.102482
# 952938001   0.322724   0.319079   0.305126   0.000000   0.000000   0.105267
# 953763001   0.605449   0.546502   0.501808   0.082062   0.023836   0.023027
# 956217002   0.375911   0.318456   0.283294   0.083795   0.024339   0.023513
# 959461001   0.314123   0.395606   0.357597   0.024064   0.116933   0.022932
#
#            111565001  111565003  111586001  111593001  ...  949143001  \
# 108775015   0.137086   0.122848   0.188705   0.137086  ...   0.112254
# 108775044   0.117260   0.121460   0.163706   0.117260  ...   0.072736
# 108775051   0.104837   0.108593   0.147420   0.104837  ...   0.054290
# 110065001   0.102496   0.043474   0.077920   0.102496  ...   0.060237
# 110065002   0.081071   0.042883   0.051798   0.081071  ...   0.017496
# ...              ...        ...        ...        ...  ...        ...
# 952937003   0.000000   0.052091   0.023792   0.000000  ...   0.039796
# 952938001   0.000000   0.053507   0.024439   0.000000  ...   0.081627
# 953763001   0.038374   0.011705   0.073190   0.038374  ...   0.164402
# 956217002   0.039185   0.011952   0.074736   0.039185  ...   0.125006
# 959461001   0.011253   0.011656   0.039153   0.011253  ...   0.065488
#
#            949198001  949323002  949594001  952267001  952937003  952938001  \
# 108775015   0.853226   0.122585   0.294175   0.128689   0.277282   0.322724
# 108775044   0.807360   0.079430   0.290852   0.109054   0.274150   0.319079
# 108775051   0.757597   0.059286   0.258739   0.104285   0.262162   0.305126
# 110065001   0.057052   0.065780   0.022536   0.093525   0.000000   0.000000
# 110065002   0.016571   0.019107   0.022229   0.072328   0.000000   0.000000
# ...              ...        ...        ...        ...        ...        ...
# 952937003   0.282333   0.188088   0.478565   0.039079   1.000000   0.921080
# 952938001   0.290008   0.237700   0.491573   0.040142   0.921080   1.000000
# 953763001   0.374841   0.179532   0.536488   0.026932   0.513146   0.582607
# 956217002   0.382758   0.292798   0.547819   0.027501   0.819842   0.727472
# 959461001   0.319845   0.223935   0.534261   0.000000   0.799552   0.709468
#
#            953763001  956217002  959461001
# 108775015   0.605449   0.375911   0.314123
# 108775044   0.546502   0.318456   0.395606
# 108775051   0.501808   0.283294   0.357597
# 110065001   0.082062   0.083795   0.024064
# 110065002   0.023836   0.024339   0.116933
# ...              ...        ...        ...
# 952937003   0.513146   0.819842   0.799552
# 952938001   0.582607   0.727472   0.709468
# 953763001   1.000000   0.666221   0.572866
# 956217002   0.666221   1.000000   0.896760
# 959461001   0.572866   0.896760   1.000000
#
# [39523 rows x 39523 columns]

# %%
# Finding the similarity in products
grouped_dataframes = []
# Processing Group wise
Groups = articles_df['index_group_name'].value_counts().index
# Iterate groups from the H&M
for x, group in enumerate(Groups):
    df = pd.DataFrame(data=similarity_sparse_matrix[x], 
                                 index=articles_df[articles_df['index_group_name'] == group]['article_id'].values,
                                 columns=articles_df[articles_df['index_group_name'] == group]['article_id'].values)
    grouped_dataframes.append(df)

# %%
grouped_dataframes[2]
# Out:
#            162074062  162074069  162074071  181160009  181448022  181448102  \
# 162074062   1.000000   0.834122   0.849635   0.000000   0.858904   0.849185
# 162074069   0.834122   1.000000   0.963029   0.000000   0.940795   0.886660
# 162074071   0.849635   0.963029   1.000000   0.000000   0.977561   0.903150
# 181160009   0.000000   0.000000   0.000000   1.000000   0.009709   0.000000
# 181448022   0.858904   0.940795   0.977561   0.009709   1.000000   0.913002
# ...              ...        ...        ...        ...        ...        ...
# 946475001   0.000000   0.000000   0.017758   0.133770   0.028804   0.000000
# 947253001   0.000000   0.000000   0.017758   0.133770   0.028804   0.000000
# 949551001   0.000000   0.000000   0.031879   0.016064   0.051708   0.000000
# 949551002   0.067170   0.000000   0.000000   0.015481   0.018775   0.071401
# 957375001   0.000000   0.000000   0.017623   0.132750   0.028584   0.000000
#
#            181448103  181448104  181448105  181448106  ...  943674001  \
# 162074062   0.861063   0.786352   0.807063   0.816563  ...   0.000000
# 162074069   0.899062   0.861327   0.884012   0.894418  ...   0.000000
# 162074071   0.915783   0.877346   0.918558   0.911053  ...   0.000000
# 181160009   0.000000   0.000000   0.000000   0.000000  ...   0.017395
# 181448022   0.925773   0.886916   0.928578   0.920991  ...   0.021097
# ...              ...        ...        ...        ...  ...        ...
# 946475001   0.000000   0.000000   0.016868   0.000000  ...   0.019443
# 947253001   0.000000   0.000000   0.016868   0.000000  ...   0.019443
# 949551001   0.000000   0.000000   0.030281   0.000000  ...   0.072611
# 949551002   0.072399   0.000000   0.000000   0.000000  ...   0.069976
# 957375001   0.000000   0.000000   0.016740   0.000000  ...   0.019294
#
#            944233001  945995002  946095001  946387001  946475001  947253001  \
# 162074062   0.000000   0.063042   0.000000        0.0   0.000000   0.000000
# 162074069   0.000000   0.048991   0.000000        0.0   0.000000   0.000000
# 162074071   0.039107   0.049902   0.000000        0.0   0.017758   0.017758
# 181160009   0.019706   0.000000   0.000000        0.0   0.133770   0.133770
# 181448022   0.063432   0.000000   0.000000        0.0   0.028804   0.028804
# ...              ...        ...        ...        ...        ...        ...
# 946475001   0.058459   0.000000   0.000000        0.0   1.000000   1.000000
# 947253001   0.058459   0.000000   0.000000        0.0   1.000000   1.000000
# 949551001   0.147662   0.827110   0.033216        0.0   0.047654   0.047654
# 949551002   0.079271   0.910457   0.032011        0.0   0.017303   0.017303
# 957375001   0.058014   0.000000   0.000000        0.0   0.760600   0.760600
#
#            949551001  949551002  957375001
# 162074062   0.000000   0.067170   0.000000
# 162074069   0.000000   0.000000   0.000000
# 162074071   0.031879   0.000000   0.017623
# 181160009   0.016064   0.015481   0.132750
# 181448022   0.051708   0.018775   0.028584
# ...              ...        ...        ...
# 946475001   0.047654   0.017303   0.760600
# 947253001   0.047654   0.017303   0.760600
# 949551001   1.000000   0.912323   0.047291
# 949551002   0.912323   1.000000   0.017171
# 957375001   0.047291   0.017171   1.000000
#
# [15086 rows x 15086 columns]

# %%
# Now we have made super easy find relationship between two articles
# For example the relationship of score of article "162074071" to "181448022" is as easy as
grouped_dataframes[2].loc[162074071][181448022]
# Out:
# 0.9775607980545375

# %%
arr1 = ['python3.6' , 'python2' ,'python3']
arr1.remove('python2')
arr1
# Out:
# ['python3.6', 'python3']

# %%
similar_count = 10
tbl = []
for i, group in enumerate(Groups):
    for j, item in enumerate(grouped_dataframes[i].index):
        top_10_matched_items = grouped_dataframes[i][item].nlargest(n=10).index
        top10 = ",".join(str(v) for v in (list(top_10_matched_items[top_10_matched_items != item])))
        row = [item, top10]
        tbl.append(row)
    # Temporary Status Update    
    print('Processing Complete --- ', group)
        
article_similarity_df = pd.DataFrame(data=tbl, columns=['article_id', 'similar_articles'])
article_similarity_df
# Out:
# Processing Complete ---  Ladieswear
# Processing Complete ---  Baby/Children
# Processing Complete ---  Divided
# Processing Complete ---  Menswear
# Processing Complete ---  Sport
#         article_id                                   similar_articles
# 0        108775015  218354001,372008001,494030013,538699001,565379...
# 1        108775044  218354021,355307042,372008010,494030010,494030...
# 2        108775051  565379021,218354045,108775044,218354021,355307...
# 3        110065001  153115019,253448001,383152002,497513001,562914...
# 4        110065002  153115021,253448002,508318008,679285008,699570...
# ...            ...                                                ...
# 105121   942053001  769667001,931349001,769683001,769684001,872686...
# 105122   942062001  769667001,942053001,931349001,769683001,769684...
# 105123   942128001  506410009,506411010,506410006,506411006,706204...
# 105124   942987001  805928002,879588001,880159001,498738034,645023...
# 105125   943264001  587088003,389388001,404441004,649521002,651548...
#
# [105126 rows x 2 columns]

# %%
# Persist File to the file system
article_similarity_df.to_csv(path + 'article-content-similarity.csv')
